# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
dset=pd.read_csv('dataset1.csv')
dset
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
range_fm=150
range_to=180
dset['Height']= np.random.randint(range_fm, range_to+1, len(dset))
print(dset['Height'])
# Out:
# 0      164
# 1      167
# 2      153
# 3      159
# 4      157
#       ...
# 453    161
# 454    165
# 455    157
# 456    160
# 457    180
# Name: Height, Length: 458, dtype: int32

# %%
dset.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     167     235
# 2   John Holland  Boston Celtics      30       SG   27     153     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     159     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     157     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
emp_percentage=dset['Team'].value_counts()
emp_percentage
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
percent_emp= pd.DataFrame(emp_percentage)
percent_emp
# Out:
#                         count
# Team
# New Orleans Pelicans       19
# Memphis Grizzlies          18
# Utah Jazz                  16
# New York Knicks            16
# Milwaukee Bucks            16
# Brooklyn Nets              15
# Portland Trail Blazers     15
# Oklahoma City Thunder      15
# Denver Nuggets             15
# Washington Wizards         15
# Miami Heat                 15
# Charlotte Hornets          15
# Atlanta Hawks              15
# San Antonio Spurs          15
# Houston Rockets            15
# Boston Celtics             15
# Indiana Pacers             15
# Detroit Pistons            15
# Cleveland Cavaliers        15
# Chicago Bulls              15
# Sacramento Kings           15
# Phoenix Suns               15
# Los Angeles Lakers         15
# Los Angeles Clippers       15
# Golden State Warriors      15
# Toronto Raptors            15
# Philadelphia 76ers         15
# Dallas Mavericks           15
# Orlando Magic              14
# Minnesota Timberwolves     14

# %%
percent_emp.rename(columns={'count':"No of employees"},inplace= True)

# %%
percent_emp['Percentage of Employee']= percent_emp['count']/len(dset) * 100

# %%
percent_emp
# Out:
#                         No of employees  Percentage of Employee
# Team
# New Orleans Pelicans                 19                4.148472
# Memphis Grizzlies                    18                3.930131
# Utah Jazz                            16                3.493450
# New York Knicks                      16                3.493450
# Milwaukee Bucks                      16                3.493450
# Brooklyn Nets                        15                3.275109
# Portland Trail Blazers               15                3.275109
# Oklahoma City Thunder                15                3.275109
# Denver Nuggets                       15                3.275109
# Washington Wizards                   15                3.275109
# Miami Heat                           15                3.275109
# Charlotte Hornets                    15                3.275109
# Atlanta Hawks                        15                3.275109
# San Antonio Spurs                    15                3.275109
# ...

# %% [markdown]
# ## 2.Segregate the employees w.r.t different positions.

# %%
dset['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
segregated= dset.groupby('Position')
for Position,group in segregated:
    print(f"Employees in {Position} Position:")
    print(group)
    print("\n")
# Out:
# Employees in C Position:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     155
# 10   Jared Sullinger          Boston Celtics       7        C   24     165
# 14      Tyler Zeller          Boston Celtics      44        C   26     156
# 23       Brook Lopez           Brooklyn Nets      11        C   28     160
# 27        Henry Sims           Brooklyn Nets      14        C   26     154
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     166
# 447      Rudy Gobert               Utah Jazz      27        C   23     153
# 455     Tibor Pleiss               Utah Jazz      21        C   26     157
# 456      Jeff Withey               Utah Jazz      24        C   26     160
# 457         Priyanka               Utah Jazz      34        C   25     180
#
#      Weight         College      Salary
# ...

# %% [markdown]
# ## 3.Find from which age group most of the employees belong to.

# %%
most_age=dset['Age'].value_counts().idxmax()
print("Most of the Employees belongs to, age group:---",most_age)
# Out:
# Most of the Employees belongs to, age group:--- 24

# %% [markdown]
# ## 4.Find out under which team and position, spending in terms of salary is high.

# %%
high_salary= dset['Salary'].sort_values(ascending=False)
high_salary_max=high_salary.max()
result= dset.loc[dset['Salary']== high_salary_max,['Team','Position','Salary'] ]
result
# Out:
#                    Team Position      Salary
# 109  Los Angeles Lakers       SF  25000000.0

# %% [markdown]
# ## 5.Find if there is any correlation between age and salary , represent it visually.

# %%
sns.set_style('darkgrid')
plt.scatter(dset['Salary'],dset['Age'])
plt.xlabel('Salary')
plt.ylabel('Age')
plt.title('Correlation Between Age and Salary')
plt.show()
